# %% [markdown]
# # Deep Inspection
# In this phase, we analyze the two tables in more detail to eliminate some inconsistent data

# %%
import numpy as np
import pandas as pd
import transformation_utils as util
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# There is an inconsistency between the team's total points for a year and the sum of the individual players' points for that team in that year. We decided to consider the sum of the player stats for each team for every year

# %%
df_players = pd.read_csv('../newData/players_teams_cleaned.csv')

stat_mappings = [
    ('fgMade', 'o_fgm'), ('ftMade', 'o_ftm'), ('threeMade', 'o_3pm'),
    ('fgAttempted', 'o_fga'), ('ftAttempted', 'o_fta'), ('threeAttempted', 'o_3pa'),
    ('oRebounds', 'o_oreb'), ('dRebounds', 'o_dreb'), ('rebounds', 'o_reb'),
    ('assists', 'o_asts'), ('steals', 'o_stl'), ('turnovers', 'o_to'), ('blocks', 'o_blk')
]

# update EAST e WEST
for side in ['EA', 'WE']:
    for player_stat, team_stat in stat_mappings:
        util.update_team_data(f'../newData/teams_{side}_cleaned.csv', df_players, player_stat, team_stat,
                         f'../newData/teams_{side}_cleaned.csv')

columns_to_remove = [
    'fgMade', 'ftMade', 'threeMade', 'fgAttempted', 'ftAttempted', 'threeAttempted',
    'oRebounds', 'dRebounds', 'rebounds', 'assists', 'steals', 'turnovers', 'blocks'
]

for path in ['../newData/teams_EA_cleaned.csv', '../newData/teams_WE_cleaned.csv']:
    df_teams_final = pd.read_csv(path)
    df_teams_final = df_teams_final.drop(columns=columns_to_remove, errors='ignore')
    df_teams_final.to_csv(path, index=False)
# Out:
# Mismatches found for o_fgm:
#     tmID  year  o_fgm  sum_fgMadePlayer  diff_fgMade
# 833  CON     1    833               NaN          NaN
# 834  CON     1    833               NaN          NaN
# 835  CON     1    833               NaN          NaN
# 836  CON     1    833               NaN          NaN
# 837  CON     1    833               NaN          NaN
# 838  CON     1    833               NaN          NaN
# 839  CON     1    833               NaN          NaN
# 840  CON     1    833               NaN          NaN
# 841  CON     1    833               NaN          NaN
# 842  CON     1    833               NaN          NaN
# 843  CON     1    833               NaN          NaN
# 844  CON     1    833               NaN          NaN
# 845  CON     1    833               NaN          NaN
# 846  CON     2    768               NaN          NaN
# 847  CON     2    768               NaN          NaN
# 848  CON     2    768               NaN          NaN
# 849  CON     2    768               NaN          NaN
# 850  CON     2    768               NaN          NaN
# 851  CON     2    768               NaN          NaN
# 852  CON     2    768               NaN          NaN
# 853  CON     2    768               NaN          NaN
# 854  CON     2    768               NaN          NaN
# 855  CON     2    768               NaN          NaN
# 856  CON     2    768               NaN          NaN
# 857  CON     2    768               NaN          NaN
# 858  CON     3    808               NaN          NaN
# 859  CON     3    808               NaN          NaN
# 860  CON     3    808               NaN          NaN
# 861  CON     3    808               NaN          NaN
# 862  CON     3    808               NaN          NaN
# 863  CON     3    808               NaN          NaN
# 864  CON     3    808               NaN          NaN
# 865  CON     3    808               NaN          NaN
# 866  CON     3    808               NaN          NaN
# 867  CON     3    808               NaN          NaN
# 868  CON     3    808               NaN          NaN
# 869  CON     3    808               NaN          NaN
# 870  CON     3    808               NaN          NaN
# 871  CON     3    808               NaN          NaN
# Mismatches found for o_ftm:
#     tmID  year  o_ftm  sum_ftMadePlayer  diff_ftMade
# 833  CON     1    397               NaN          NaN
# 834  CON     1    397               NaN          NaN
# 835  CON     1    397               NaN          NaN
# 836  CON     1    397               NaN          NaN
# 837  CON     1    397               NaN          NaN
# 838  CON     1    397               NaN          NaN
# 839  CON     1    397               NaN          NaN
# 840  CON     1    397               NaN          NaN
# 841  CON     1    397               NaN          NaN
# 842  CON     1    397               NaN          NaN
# 843  CON     1    397               NaN          NaN
# 844  CON     1    397               NaN          NaN
# 845  CON     1    397               NaN          NaN
# 846  CON     2    430               NaN          NaN
# 847  CON     2    430               NaN          NaN
# 848  CON     2    430               NaN          NaN
# 849  CON     2    430               NaN          NaN
# 850  CON     2    430               NaN          NaN
# 851  CON     2    430               NaN          NaN
# 852  CON     2    430               NaN          NaN
# 853  CON     2    430               NaN          NaN
# 854  CON     2    430               NaN          NaN
# 855  CON     2    430               NaN          NaN
# 856  CON     2    430               NaN          NaN
# 857  CON     2    430               NaN          NaN
# 858  CON     3    493               NaN          NaN
# 859  CON     3    493               NaN          NaN
# 860  CON     3    493               NaN          NaN
# 861  CON     3    493               NaN          NaN
# 862  CON     3    493               NaN          NaN
# 863  CON     3    493               NaN          NaN
# 864  CON     3    493               NaN          NaN
# 865  CON     3    493               NaN          NaN
# 866  CON     3    493               NaN          NaN
# 867  CON     3    493               NaN          NaN
# 868  CON     3    493               NaN          NaN
# 869  CON     3    493               NaN          NaN
# 870  CON     3    493               NaN          NaN
# 871  CON     3    493               NaN          NaN
# Mismatches found for o_3pm:
#     tmID  year  o_3pm  sum_threeMadePlayer  diff_threeMade
# 833  CON     1    145                  NaN             NaN
# 834  CON     1    145                  NaN             NaN
# 835  CON     1    145                  NaN             NaN
# 836  CON     1    145                  NaN             NaN
# 837  CON     1    145                  NaN             NaN
# 838  CON     1    145                  NaN             NaN
# 839  CON     1    145                  NaN             NaN
# 840  CON     1    145                  NaN             NaN
# 841  CON     1    145                  NaN             NaN
# 842  CON     1    145                  NaN             NaN
# 843  CON     1    145                  NaN             NaN
# 844  CON     1    145                  NaN             NaN
# 845  CON     1    145                  NaN             NaN
# 846  CON     2    174                  NaN             NaN
# 847  CON     2    174                  NaN             NaN
# 848  CON     2    174                  NaN             NaN
# 849  CON     2    174                  NaN             NaN
# 850  CON     2    174                  NaN             NaN
# 851  CON     2    174                  NaN             NaN
# 852  CON     2    174                  NaN             NaN
# 853  CON     2    174                  NaN             NaN
# 854  CON     2    174                  NaN             NaN
# 855  CON     2    174                  NaN             NaN
# 856  CON     2    174                  NaN             NaN
# 857  CON     2    174                  NaN             NaN
# 858  CON     3    145                  NaN             NaN
# 859  CON     3    145                  NaN             NaN
# 860  CON     3    145                  NaN             NaN
# 861  CON     3    145                  NaN             NaN
# 862  CON     3    145                  NaN             NaN
# 863  CON     3    145                  NaN             NaN
# 864  CON     3    145                  NaN             NaN
# 865  CON     3    145                  NaN             NaN
# 866  CON     3    145                  NaN             NaN
# 867  CON     3    145                  NaN             NaN
# 868  CON     3    145                  NaN             NaN
# 869  CON     3    145                  NaN             NaN
# 870  CON     3    145                  NaN             NaN
# 871  CON     3    145                  NaN             NaN
# Mismatches found for o_fga:
#     tmID  year  o_fga  sum_fgAttemptedPlayer  diff_fgAttempted
# 833  CON     1   1911                    NaN               NaN
# 834  CON     1   1911                    NaN               NaN
# 835  CON     1   1911                    NaN               NaN
# 836  CON     1   1911                    NaN               NaN
# 837  CON     1   1911                    NaN               NaN
# 838  CON     1   1911                    NaN               NaN
# 839  CON     1   1911                    NaN               NaN
# 840  CON     1   1911                    NaN               NaN
# 841  CON     1   1911                    NaN               NaN
# 842  CON     1   1911                    NaN               NaN
# 843  CON     1   1911                    NaN               NaN
# 844  CON     1   1911                    NaN               NaN
# 845  CON     1   1911                    NaN               NaN
# 846  CON     2   1914                    NaN               NaN
# 847  CON     2   1914                    NaN               NaN
# 848  CON     2   1914                    NaN               NaN
# 849  CON     2   1914                    NaN               NaN
# 850  CON     2   1914                    NaN               NaN
# 851  CON     2   1914                    NaN               NaN
# 852  CON     2   1914                    NaN               NaN
# 853  CON     2   1914                    NaN               NaN
# 854  CON     2   1914                    NaN               NaN
# 855  CON     2   1914                    NaN               NaN
# 856  CON     2   1914                    NaN               NaN
# 857  CON     2   1914                    NaN               NaN
# 858  CON     3   1914                    NaN               NaN
# 859  CON     3   1914                    NaN               NaN
# 860  CON     3   1914                    NaN               NaN
# 861  CON     3   1914                    NaN               NaN
# 862  CON     3   1914                    NaN               NaN
# 863  CON     3   1914                    NaN               NaN
# 864  CON     3   1914                    NaN               NaN
# 865  CON     3   1914                    NaN               NaN
# 866  CON     3   1914                    NaN               NaN
# 867  CON     3   1914                    NaN               NaN
# 868  CON     3   1914                    NaN               NaN
# 869  CON     3   1914                    NaN               NaN
# 870  CON     3   1914                    NaN               NaN
# 871  CON     3   1914                    NaN               NaN
# Mismatches found for o_fta:
#     tmID  year  o_fta  sum_ftAttemptedPlayer  diff_ftAttempted
# 833  CON     1    546                    NaN               NaN
# 834  CON     1    546                    NaN               NaN
# 835  CON     1    546                    NaN               NaN
# 836  CON     1    546                    NaN               NaN
# 837  CON     1    546                    NaN               NaN
# 838  CON     1    546                    NaN               NaN
# 839  CON     1    546                    NaN               NaN
# 840  CON     1    546                    NaN               NaN
# 841  CON     1    546                    NaN               NaN
# 842  CON     1    546                    NaN               NaN
# 843  CON     1    546                    NaN               NaN
# 844  CON     1    546                    NaN               NaN
# 845  CON     1    546                    NaN               NaN
# 846  CON     2    587                    NaN               NaN
# 847  CON     2    587                    NaN               NaN
# 848  CON     2    587                    NaN               NaN
# 849  CON     2    587                    NaN               NaN
# 850  CON     2    587                    NaN               NaN
# 851  CON     2    587                    NaN               NaN
# 852  CON     2    587                    NaN               NaN
# 853  CON     2    587                    NaN               NaN
# 854  CON     2    587                    NaN               NaN
# 855  CON     2    587                    NaN               NaN
# 856  CON     2    587                    NaN               NaN
# 857  CON     2    587                    NaN               NaN
# 858  CON     3    646                    NaN               NaN
# 859  CON     3    646                    NaN               NaN
# 860  CON     3    646                    NaN               NaN
# 861  CON     3    646                    NaN               NaN
# 862  CON     3    646                    NaN               NaN
# 863  CON     3    646                    NaN               NaN
# 864  CON     3    646                    NaN               NaN
# 865  CON     3    646                    NaN               NaN
# 866  CON     3    646                    NaN               NaN
# 867  CON     3    646                    NaN               NaN
# 868  CON     3    646                    NaN               NaN
# 869  CON     3    646                    NaN               NaN
# 870  CON     3    646                    NaN               NaN
# 871  CON     3    646                    NaN               NaN
# Mismatches found for o_3pa:
#     tmID  year  o_3pa  sum_threeAttemptedPlayer  diff_threeAttempted
# 833  CON     1    424                       NaN                  NaN
# 834  CON     1    424                       NaN                  NaN
# 835  CON     1    424                       NaN                  NaN
# 836  CON     1    424                       NaN                  NaN
# 837  CON     1    424                       NaN                  NaN
# 838  CON     1    424                       NaN                  NaN
# 839  CON     1    424                       NaN                  NaN
# 840  CON     1    424                       NaN                  NaN
# 841  CON     1    424                       NaN                  NaN
# 842  CON     1    424                       NaN                  NaN
# 843  CON     1    424                       NaN                  NaN
# 844  CON     1    424                       NaN                  NaN
# 845  CON     1    424                       NaN                  NaN
# 846  CON     2    532                       NaN                  NaN
# 847  CON     2    532                       NaN                  NaN
# 848  CON     2    532                       NaN                  NaN
# 849  CON     2    532                       NaN                  NaN
# 850  CON     2    532                       NaN                  NaN
# 851  CON     2    532                       NaN                  NaN
# 852  CON     2    532                       NaN                  NaN
# 853  CON     2    532                       NaN                  NaN
# 854  CON     2    532                       NaN                  NaN
# 855  CON     2    532                       NaN                  NaN
# 856  CON     2    532                       NaN                  NaN
# 857  CON     2    532                       NaN                  NaN
# 858  CON     3    461                       NaN                  NaN
# 859  CON     3    461                       NaN                  NaN
# 860  CON     3    461                       NaN                  NaN
# 861  CON     3    461                       NaN                  NaN
# 862  CON     3    461                       NaN                  NaN
# 863  CON     3    461                       NaN                  NaN
# 864  CON     3    461                       NaN                  NaN
# 865  CON     3    461                       NaN                  NaN
# 866  CON     3    461                       NaN                  NaN
# 867  CON     3    461                       NaN                  NaN
# 868  CON     3    461                       NaN                  NaN
# 869  CON     3    461                       NaN                  NaN
# 870  CON     3    461                       NaN                  NaN
# 871  CON     3    461                       NaN                  NaN
# Mismatches found for o_oreb:
#     tmID  year  o_oreb  sum_oReboundsPlayer  diff_oRebounds
# 833  CON     1     319                  NaN             NaN
# 834  CON     1     319                  NaN             NaN
# 835  CON     1     319                  NaN             NaN
# 836  CON     1     319                  NaN             NaN
# 837  CON     1     319                  NaN             NaN
# 838  CON     1     319                  NaN             NaN
# 839  CON     1     319                  NaN             NaN
# 840  CON     1     319                  NaN             NaN
# 841  CON     1     319                  NaN             NaN
# 842  CON     1     319                  NaN             NaN
# 843  CON     1     319                  NaN             NaN
# 844  CON     1     319                  NaN             NaN
# 845  CON     1     319                  NaN             NaN
# 846  CON     2     356                  NaN             NaN
# 847  CON     2     356                  NaN             NaN
# 848  CON     2     356                  NaN             NaN
# 849  CON     2     356                  NaN             NaN
# 850  CON     2     356                  NaN             NaN
# 851  CON     2     356                  NaN             NaN
# 852  CON     2     356                  NaN             NaN
# 853  CON     2     356                  NaN             NaN
# 854  CON     2     356                  NaN             NaN
# 855  CON     2     356                  NaN             NaN
# 856  CON     2     356                  NaN             NaN
# 857  CON     2     356                  NaN             NaN
# 858  CON     3     320                  NaN             NaN
# 859  CON     3     320                  NaN             NaN
# 860  CON     3     320                  NaN             NaN
# 861  CON     3     320                  NaN             NaN
# 862  CON     3     320                  NaN             NaN
# 863  CON     3     320                  NaN             NaN
# 864  CON     3     320                  NaN             NaN
# 865  CON     3     320                  NaN             NaN
# 866  CON     3     320                  NaN             NaN
# 867  CON     3     320                  NaN             NaN
# 868  CON     3     320                  NaN             NaN
# 869  CON     3     320                  NaN             NaN
# 870  CON     3     320                  NaN             NaN
# 871  CON     3     320                  NaN             NaN
# Mismatches found for o_dreb:
#     tmID  year  o_dreb  sum_dReboundsPlayer  diff_dRebounds
# 833  CON     1     606                  NaN             NaN
# 834  CON     1     606                  NaN             NaN
# 835  CON     1     606                  NaN             NaN
# 836  CON     1     606                  NaN             NaN
# 837  CON     1     606                  NaN             NaN
# 838  CON     1     606                  NaN             NaN
# 839  CON     1     606                  NaN             NaN
# 840  CON     1     606                  NaN             NaN
# 841  CON     1     606                  NaN             NaN
# 842  CON     1     606                  NaN             NaN
# 843  CON     1     606                  NaN             NaN
# 844  CON     1     606                  NaN             NaN
# 845  CON     1     606                  NaN             NaN
# 846  CON     2     614                  NaN             NaN
# 847  CON     2     614                  NaN             NaN
# 848  CON     2     614                  NaN             NaN
# 849  CON     2     614                  NaN             NaN
# 850  CON     2     614                  NaN             NaN
# 851  CON     2     614                  NaN             NaN
# 852  CON     2     614                  NaN             NaN
# 853  CON     2     614                  NaN             NaN
# 854  CON     2     614                  NaN             NaN
# 855  CON     2     614                  NaN             NaN
# 856  CON     2     614                  NaN             NaN
# 857  CON     2     614                  NaN             NaN
# 858  CON     3     595                  NaN             NaN
# 859  CON     3     595                  NaN             NaN
# 860  CON     3     595                  NaN             NaN
# 861  CON     3     595                  NaN             NaN
# 862  CON     3     595                  NaN             NaN
# 863  CON     3     595                  NaN             NaN
# 864  CON     3     595                  NaN             NaN
# 865  CON     3     595                  NaN             NaN
# 866  CON     3     595                  NaN             NaN
# 867  CON     3     595                  NaN             NaN
# 868  CON     3     595                  NaN             NaN
# 869  CON     3     595                  NaN             NaN
# 870  CON     3     595                  NaN             NaN
# 871  CON     3     595                  NaN             NaN
# Mismatches found for o_reb:
#     tmID  year  o_reb  sum_reboundsPlayer  diff_rebounds
# 833  CON     1    925                 NaN            NaN
# 834  CON     1    925                 NaN            NaN
# 835  CON     1    925                 NaN            NaN
# 836  CON     1    925                 NaN            NaN
# 837  CON     1    925                 NaN            NaN
# 838  CON     1    925                 NaN            NaN
# 839  CON     1    925                 NaN            NaN
# 840  CON     1    925                 NaN            NaN
# 841  CON     1    925                 NaN            NaN
# 842  CON     1    925                 NaN            NaN
# 843  CON     1    925                 NaN            NaN
# 844  CON     1    925                 NaN            NaN
# 845  CON     1    925                 NaN            NaN
# 846  CON     2    970                 NaN            NaN
# 847  CON     2    970                 NaN            NaN
# 848  CON     2    970                 NaN            NaN
# 849  CON     2    970                 NaN            NaN
# 850  CON     2    970                 NaN            NaN
# 851  CON     2    970                 NaN            NaN
# 852  CON     2    970                 NaN            NaN
# 853  CON     2    970                 NaN            NaN
# 854  CON     2    970                 NaN            NaN
# 855  CON     2    970                 NaN            NaN
# 856  CON     2    970                 NaN            NaN
# 857  CON     2    970                 NaN            NaN
# 858  CON     3    915                 NaN            NaN
# 859  CON     3    915                 NaN            NaN
# 860  CON     3    915                 NaN            NaN
# 861  CON     3    915                 NaN            NaN
# 862  CON     3    915                 NaN            NaN
# 863  CON     3    915                 NaN            NaN
# 864  CON     3    915                 NaN            NaN
# 865  CON     3    915                 NaN            NaN
# 866  CON     3    915                 NaN            NaN
# 867  CON     3    915                 NaN            NaN
# 868  CON     3    915                 NaN            NaN
# 869  CON     3    915                 NaN            NaN
# 870  CON     3    915                 NaN            NaN
# 871  CON     3    915                 NaN            NaN
# Mismatches found for o_asts:
#     tmID  year  o_asts  sum_assistsPlayer  diff_assists
# 833  CON     1     473                NaN           NaN
# 834  CON     1     473                NaN           NaN
# 835  CON     1     473                NaN           NaN
# 836  CON     1     473                NaN           NaN
# 837  CON     1     473                NaN           NaN
# 838  CON     1     473                NaN           NaN
# 839  CON     1     473                NaN           NaN
# 840  CON     1     473                NaN           NaN
# 841  CON     1     473                NaN           NaN
# 842  CON     1     473                NaN           NaN
# 843  CON     1     473                NaN           NaN
# 844  CON     1     473                NaN           NaN
# 845  CON     1     473                NaN           NaN
# 846  CON     2     452                NaN           NaN
# 847  CON     2     452                NaN           NaN
# 848  CON     2     452                NaN           NaN
# 849  CON     2     452                NaN           NaN
# 850  CON     2     452                NaN           NaN
# 851  CON     2     452                NaN           NaN
# 852  CON     2     452                NaN           NaN
# 853  CON     2     452                NaN           NaN
# 854  CON     2     452                NaN           NaN
# 855  CON     2     452                NaN           NaN
# 856  CON     2     452                NaN           NaN
# 857  CON     2     452                NaN           NaN
# 858  CON     3     446                NaN           NaN
# 859  CON     3     446                NaN           NaN
# 860  CON     3     446                NaN           NaN
# 861  CON     3     446                NaN           NaN
# 862  CON     3     446                NaN           NaN
# 863  CON     3     446                NaN           NaN
# 864  CON     3     446                NaN           NaN
# 865  CON     3     446                NaN           NaN
# 866  CON     3     446                NaN           NaN
# 867  CON     3     446                NaN           NaN
# 868  CON     3     446                NaN           NaN
# 869  CON     3     446                NaN           NaN
# 870  CON     3     446                NaN           NaN
# 871  CON     3     446                NaN           NaN
# Mismatches found for o_stl:
#     tmID  year  o_stl  sum_stealsPlayer  diff_steals
# 833  CON     1    255               NaN          NaN
# 834  CON     1    255               NaN          NaN
# 835  CON     1    255               NaN          NaN
# 836  CON     1    255               NaN          NaN
# 837  CON     1    255               NaN          NaN
# 838  CON     1    255               NaN          NaN
# 839  CON     1    255               NaN          NaN
# 840  CON     1    255               NaN          NaN
# 841  CON     1    255               NaN          NaN
# 842  CON     1    255               NaN          NaN
# 843  CON     1    255               NaN          NaN
# 844  CON     1    255               NaN          NaN
# 845  CON     1    255               NaN          NaN
# 846  CON     2    320               NaN          NaN
# 847  CON     2    320               NaN          NaN
# 848  CON     2    320               NaN          NaN
# 849  CON     2    320               NaN          NaN
# 850  CON     2    320               NaN          NaN
# 851  CON     2    320               NaN          NaN
# 852  CON     2    320               NaN          NaN
# 853  CON     2    320               NaN          NaN
# 854  CON     2    320               NaN          NaN
# 855  CON     2    320               NaN          NaN
# 856  CON     2    320               NaN          NaN
# 857  CON     2    320               NaN          NaN
# 858  CON     3    295               NaN          NaN
# 859  CON     3    295               NaN          NaN
# 860  CON     3    295               NaN          NaN
# 861  CON     3    295               NaN          NaN
# 862  CON     3    295               NaN          NaN
# 863  CON     3    295               NaN          NaN
# 864  CON     3    295               NaN          NaN
# 865  CON     3    295               NaN          NaN
# 866  CON     3    295               NaN          NaN
# 867  CON     3    295               NaN          NaN
# 868  CON     3    295               NaN          NaN
# 869  CON     3    295               NaN          NaN
# 870  CON     3    295               NaN          NaN
# 871  CON     3    295               NaN          NaN
# Mismatches found for o_to:
#     tmID  year  o_to  sum_turnoversPlayer  diff_turnovers
# 833  CON     1   474                  NaN             NaN
# 834  CON     1   474                  NaN             NaN
# 835  CON     1   474                  NaN             NaN
# 836  CON     1   474                  NaN             NaN
# 837  CON     1   474                  NaN             NaN
# 838  CON     1   474                  NaN             NaN
# 839  CON     1   474                  NaN             NaN
# 840  CON     1   474                  NaN             NaN
# 841  CON     1   474                  NaN             NaN
# 842  CON     1   474                  NaN             NaN
# 843  CON     1   474                  NaN             NaN
# 844  CON     1   474                  NaN             NaN
# 845  CON     1   474                  NaN             NaN
# 846  CON     2   524                  NaN             NaN
# 847  CON     2   524                  NaN             NaN
# 848  CON     2   524                  NaN             NaN
# 849  CON     2   524                  NaN             NaN
# 850  CON     2   524                  NaN             NaN
# 851  CON     2   524                  NaN             NaN
# 852  CON     2   524                  NaN             NaN
# 853  CON     2   524                  NaN             NaN
# 854  CON     2   524                  NaN             NaN
# 855  CON     2   524                  NaN             NaN
# 856  CON     2   524                  NaN             NaN
# 857  CON     2   524                  NaN             NaN
# 858  CON     3   450                  NaN             NaN
# 859  CON     3   450                  NaN             NaN
# 860  CON     3   450                  NaN             NaN
# 861  CON     3   450                  NaN             NaN
# 862  CON     3   450                  NaN             NaN
# 863  CON     3   450                  NaN             NaN
# 864  CON     3   450                  NaN             NaN
# 865  CON     3   450                  NaN             NaN
# 866  CON     3   450                  NaN             NaN
# 867  CON     3   450                  NaN             NaN
# 868  CON     3   450                  NaN             NaN
# 869  CON     3   450                  NaN             NaN
# 870  CON     3   450                  NaN             NaN
# 871  CON     3   450                  NaN             NaN
# Mismatches found for o_blk:
#     tmID  year  o_blk  sum_blocksPlayer  diff_blocks
# 833  CON     1    130               NaN          NaN
# 834  CON     1    130               NaN          NaN
# 835  CON     1    130               NaN          NaN
# 836  CON     1    130               NaN          NaN
# 837  CON     1    130               NaN          NaN
# 838  CON     1    130               NaN          NaN
# 839  CON     1    130               NaN          NaN
# 840  CON     1    130               NaN          NaN
# 841  CON     1    130               NaN          NaN
# 842  CON     1    130               NaN          NaN
# 843  CON     1    130               NaN          NaN
# 844  CON     1    130               NaN          NaN
# 845  CON     1    130               NaN          NaN
# 846  CON     2    125               NaN          NaN
# 847  CON     2    125               NaN          NaN
# 848  CON     2    125               NaN          NaN
# 849  CON     2    125               NaN          NaN
# 850  CON     2    125               NaN          NaN
# 851  CON     2    125               NaN          NaN
# 852  CON     2    125               NaN          NaN
# 853  CON     2    125               NaN          NaN
# 854  CON     2    125               NaN          NaN
# 855  CON     2    125               NaN          NaN
# 856  CON     2    125               NaN          NaN
# 857  CON     2    125               NaN          NaN
# 858  CON     3    113               NaN          NaN
# 859  CON     3    113               NaN          NaN
# 860  CON     3    113               NaN          NaN
# 861  CON     3    113               NaN          NaN
# 862  CON     3    113               NaN          NaN
# 863  CON     3    113               NaN          NaN
# 864  CON     3    113               NaN          NaN
# 865  CON     3    113               NaN          NaN
# 866  CON     3    113               NaN          NaN
# 867  CON     3    113               NaN          NaN
# 868  CON     3    113               NaN          NaN
# 869  CON     3    113               NaN          NaN
# 870  CON     3    113               NaN          NaN
# 871  CON     3    113               NaN          NaN
# Mismatches found for o_fgm:
#      tmID  year  o_fgm  sum_fgMadePlayer  diff_fgMade
# 1057  SAS     1    858               NaN          NaN
# 1058  SAS     1    858               NaN          NaN
# 1059  SAS     1    858               NaN          NaN
# 1060  SAS     1    858               NaN          NaN
# 1061  SAS     1    858               NaN          NaN
# 1062  SAS     1    858               NaN          NaN
# 1063  SAS     1    858               NaN          NaN
# 1064  SAS     1    858               NaN          NaN
# 1065  SAS     1    858               NaN          NaN
# 1066  SAS     1    858               NaN          NaN
# 1067  SAS     1    858               NaN          NaN
# 1068  SAS     1    858               NaN          NaN
# 1069  SAS     1    858               NaN          NaN
# 1070  SAS     1    858               NaN          NaN
# 1071  SAS     2    811               NaN          NaN
# 1072  SAS     2    811               NaN          NaN
# 1073  SAS     2    811               NaN          NaN
# 1074  SAS     2    811               NaN          NaN
# 1075  SAS     2    811               NaN          NaN
# 1076  SAS     2    811               NaN          NaN
# 1077  SAS     2    811               NaN          NaN
# 1078  SAS     2    811               NaN          NaN
# 1079  SAS     2    811               NaN          NaN
# 1080  SAS     2    811               NaN          NaN
# 1081  SAS     2    811               NaN          NaN
# 1082  SAS     2    811               NaN          NaN
# 1083  SAS     2    811               NaN          NaN
# 1084  SAS     2    811               NaN          NaN
# 1085  SAS     2    811               NaN          NaN
# 1086  SAS     2    811               NaN          NaN
# 1087  SAS     2    811               NaN          NaN
# 1088  SAS     2    811               NaN          NaN
# 1089  SAS     2    811               NaN          NaN
# 1090  SAS     2    811               NaN          NaN
# 1091  SAS     2    811               NaN          NaN
# 1092  SAS     2    811               NaN          NaN
# 1093  SAS     2    811               NaN          NaN
# 1094  SAS     2    811               NaN          NaN
# 1095  SAS     3    843               NaN          NaN
# 1096  SAS     3    843               NaN          NaN
# 1097  SAS     3    843               NaN          NaN
# 1098  SAS     3    843               NaN          NaN
# 1099  SAS     3    843               NaN          NaN
# 1100  SAS     3    843               NaN          NaN
# 1101  SAS     3    843               NaN          NaN
# 1102  SAS     3    843               NaN          NaN
# 1103  SAS     3    843               NaN          NaN
# 1104  SAS     3    843               NaN          NaN
# 1105  SAS     3    843               NaN          NaN
# 1106  SAS     3    843               NaN          NaN
# 1107  SAS     3    843               NaN          NaN
# Mismatches found for o_ftm:
#      tmID  year  o_ftm  sum_ftMadePlayer  diff_ftMade
# 1057  SAS     1    609               NaN          NaN
# 1058  SAS     1    609               NaN          NaN
# 1059  SAS     1    609               NaN          NaN
# 1060  SAS     1    609               NaN          NaN
# 1061  SAS     1    609               NaN          NaN
# 1062  SAS     1    609               NaN          NaN
# 1063  SAS     1    609               NaN          NaN
# 1064  SAS     1    609               NaN          NaN
# 1065  SAS     1    609               NaN          NaN
# 1066  SAS     1    609               NaN          NaN
# 1067  SAS     1    609               NaN          NaN
# 1068  SAS     1    609               NaN          NaN
# 1069  SAS     1    609               NaN          NaN
# 1070  SAS     1    609               NaN          NaN
# 1071  SAS     2    507               NaN          NaN
# 1072  SAS     2    507               NaN          NaN
# 1073  SAS     2    507               NaN          NaN
# 1074  SAS     2    507               NaN          NaN
# 1075  SAS     2    507               NaN          NaN
# 1076  SAS     2    507               NaN          NaN
# 1077  SAS     2    507               NaN          NaN
# 1078  SAS     2    507               NaN          NaN
# 1079  SAS     2    507               NaN          NaN
# 1080  SAS     2    507               NaN          NaN
# 1081  SAS     2    507               NaN          NaN
# 1082  SAS     2    507               NaN          NaN
# 1083  SAS     2    507               NaN          NaN
# 1084  SAS     2    507               NaN          NaN
# 1085  SAS     2    507               NaN          NaN
# 1086  SAS     2    507               NaN          NaN
# 1087  SAS     2    507               NaN          NaN
# 1088  SAS     2    507               NaN          NaN
# 1089  SAS     2    507               NaN          NaN
# 1090  SAS     2    507               NaN          NaN
# 1091  SAS     2    507               NaN          NaN
# 1092  SAS     2    507               NaN          NaN
# 1093  SAS     2    507               NaN          NaN
# 1094  SAS     2    507               NaN          NaN
# 1095  SAS     3    643               NaN          NaN
# 1096  SAS     3    643               NaN          NaN
# 1097  SAS     3    643               NaN          NaN
# 1098  SAS     3    643               NaN          NaN
# 1099  SAS     3    643               NaN          NaN
# 1100  SAS     3    643               NaN          NaN
# 1101  SAS     3    643               NaN          NaN
# 1102  SAS     3    643               NaN          NaN
# 1103  SAS     3    643               NaN          NaN
# 1104  SAS     3    643               NaN          NaN
# 1105  SAS     3    643               NaN          NaN
# 1106  SAS     3    643               NaN          NaN
# 1107  SAS     3    643               NaN          NaN
# Mismatches found for o_3pm:
#      tmID  year  o_3pm  sum_threeMadePlayer  diff_threeMade
# 1057  SAS     1     88                  NaN             NaN
# 1058  SAS     1     88                  NaN             NaN
# 1059  SAS     1     88                  NaN             NaN
# 1060  SAS     1     88                  NaN             NaN
# 1061  SAS     1     88                  NaN             NaN
# 1062  SAS     1     88                  NaN             NaN
# 1063  SAS     1     88                  NaN             NaN
# 1064  SAS     1     88                  NaN             NaN
# 1065  SAS     1     88                  NaN             NaN
# 1066  SAS     1     88                  NaN             NaN
# 1067  SAS     1     88                  NaN             NaN
# 1068  SAS     1     88                  NaN             NaN
# 1069  SAS     1     88                  NaN             NaN
# 1070  SAS     1     88                  NaN             NaN
# 1071  SAS     2     78                  NaN             NaN
# 1072  SAS     2     78                  NaN             NaN
# 1073  SAS     2     78                  NaN             NaN
# 1074  SAS     2     78                  NaN             NaN
# 1075  SAS     2     78                  NaN             NaN
# 1076  SAS     2     78                  NaN             NaN
# 1077  SAS     2     78                  NaN             NaN
# 1078  SAS     2     78                  NaN             NaN
# 1079  SAS     2     78                  NaN             NaN
# 1080  SAS     2     78                  NaN             NaN
# 1081  SAS     2     78                  NaN             NaN
# 1082  SAS     2     78                  NaN             NaN
# 1083  SAS     2     78                  NaN             NaN
# 1084  SAS     2     78                  NaN             NaN
# 1085  SAS     2     78                  NaN             NaN
# 1086  SAS     2     78                  NaN             NaN
# 1087  SAS     2     78                  NaN             NaN
# 1088  SAS     2     78                  NaN             NaN
# 1089  SAS     2     78                  NaN             NaN
# 1090  SAS     2     78                  NaN             NaN
# 1091  SAS     2     78                  NaN             NaN
# 1092  SAS     2     78                  NaN             NaN
# 1093  SAS     2     78                  NaN             NaN
# 1094  SAS     2     78                  NaN             NaN
# 1095  SAS     3     89                  NaN             NaN
# 1096  SAS     3     89                  NaN             NaN
# 1097  SAS     3     89                  NaN             NaN
# 1098  SAS     3     89                  NaN             NaN
# 1099  SAS     3     89                  NaN             NaN
# 1100  SAS     3     89                  NaN             NaN
# 1101  SAS     3     89                  NaN             NaN
# 1102  SAS     3     89                  NaN             NaN
# 1103  SAS     3     89                  NaN             NaN
# 1104  SAS     3     89                  NaN             NaN
# 1105  SAS     3     89                  NaN             NaN
# 1106  SAS     3     89                  NaN             NaN
# 1107  SAS     3     89                  NaN             NaN
# Mismatches found for o_fga:
#      tmID  year  o_fga  sum_fgAttemptedPlayer  diff_fgAttempted
# 1057  SAS     1   1896                    NaN               NaN
# 1058  SAS     1   1896                    NaN               NaN
# 1059  SAS     1   1896                    NaN               NaN
# 1060  SAS     1   1896                    NaN               NaN
# 1061  SAS     1   1896                    NaN               NaN
# 1062  SAS     1   1896                    NaN               NaN
# 1063  SAS     1   1896                    NaN               NaN
# 1064  SAS     1   1896                    NaN               NaN
# 1065  SAS     1   1896                    NaN               NaN
# 1066  SAS     1   1896                    NaN               NaN
# 1067  SAS     1   1896                    NaN               NaN
# 1068  SAS     1   1896                    NaN               NaN
# 1069  SAS     1   1896                    NaN               NaN
# 1070  SAS     1   1896                    NaN               NaN
# 1071  SAS     2   1849                    NaN               NaN
# 1072  SAS     2   1849                    NaN               NaN
# 1073  SAS     2   1849                    NaN               NaN
# 1074  SAS     2   1849                    NaN               NaN
# 1075  SAS     2   1849                    NaN               NaN
# 1076  SAS     2   1849                    NaN               NaN
# 1077  SAS     2   1849                    NaN               NaN
# 1078  SAS     2   1849                    NaN               NaN
# 1079  SAS     2   1849                    NaN               NaN
# 1080  SAS     2   1849                    NaN               NaN
# 1081  SAS     2   1849                    NaN               NaN
# 1082  SAS     2   1849                    NaN               NaN
# 1083  SAS     2   1849                    NaN               NaN
# 1084  SAS     2   1849                    NaN               NaN
# 1085  SAS     2   1849                    NaN               NaN
# 1086  SAS     2   1849                    NaN               NaN
# 1087  SAS     2   1849                    NaN               NaN
# 1088  SAS     2   1849                    NaN               NaN
# 1089  SAS     2   1849                    NaN               NaN
# 1090  SAS     2   1849                    NaN               NaN
# 1091  SAS     2   1849                    NaN               NaN
# 1092  SAS     2   1849                    NaN               NaN
# 1093  SAS     2   1849                    NaN               NaN
# 1094  SAS     2   1849                    NaN               NaN
# 1095  SAS     3   1911                    NaN               NaN
# 1096  SAS     3   1911                    NaN               NaN
# 1097  SAS     3   1911                    NaN               NaN
# 1098  SAS     3   1911                    NaN               NaN
# 1099  SAS     3   1911                    NaN               NaN
# 1100  SAS     3   1911                    NaN               NaN
# 1101  SAS     3   1911                    NaN               NaN
# 1102  SAS     3   1911                    NaN               NaN
# 1103  SAS     3   1911                    NaN               NaN
# 1104  SAS     3   1911                    NaN               NaN
# 1105  SAS     3   1911                    NaN               NaN
# 1106  SAS     3   1911                    NaN               NaN
# 1107  SAS     3   1911                    NaN               NaN
# Mismatches found for o_fta:
#      tmID  year  o_fta  sum_ftAttemptedPlayer  diff_ftAttempted
# 1057  SAS     1    790                    NaN               NaN
# 1058  SAS     1    790                    NaN               NaN
# 1059  SAS     1    790                    NaN               NaN
# 1060  SAS     1    790                    NaN               NaN
# 1061  SAS     1    790                    NaN               NaN
# 1062  SAS     1    790                    NaN               NaN
# 1063  SAS     1    790                    NaN               NaN
# 1064  SAS     1    790                    NaN               NaN
# 1065  SAS     1    790                    NaN               NaN
# 1066  SAS     1    790                    NaN               NaN
# 1067  SAS     1    790                    NaN               NaN
# 1068  SAS     1    790                    NaN               NaN
# 1069  SAS     1    790                    NaN               NaN
# 1070  SAS     1    790                    NaN               NaN
# 1071  SAS     2    675                    NaN               NaN
# 1072  SAS     2    675                    NaN               NaN
# 1073  SAS     2    675                    NaN               NaN
# 1074  SAS     2    675                    NaN               NaN
# 1075  SAS     2    675                    NaN               NaN
# 1076  SAS     2    675                    NaN               NaN
# 1077  SAS     2    675                    NaN               NaN
# 1078  SAS     2    675                    NaN               NaN
# 1079  SAS     2    675                    NaN               NaN
# 1080  SAS     2    675                    NaN               NaN
# 1081  SAS     2    675                    NaN               NaN
# 1082  SAS     2    675                    NaN               NaN
# 1083  SAS     2    675                    NaN               NaN
# 1084  SAS     2    675                    NaN               NaN
# 1085  SAS     2    675                    NaN               NaN
# 1086  SAS     2    675                    NaN               NaN
# 1087  SAS     2    675                    NaN               NaN
# 1088  SAS     2    675                    NaN               NaN
# 1089  SAS     2    675                    NaN               NaN
# 1090  SAS     2    675                    NaN               NaN
# 1091  SAS     2    675                    NaN               NaN
# 1092  SAS     2    675                    NaN               NaN
# 1093  SAS     2    675                    NaN               NaN
# 1094  SAS     2    675                    NaN               NaN
# 1095  SAS     3    844                    NaN               NaN
# 1096  SAS     3    844                    NaN               NaN
# 1097  SAS     3    844                    NaN               NaN
# 1098  SAS     3    844                    NaN               NaN
# 1099  SAS     3    844                    NaN               NaN
# 1100  SAS     3    844                    NaN               NaN
# 1101  SAS     3    844                    NaN               NaN
# 1102  SAS     3    844                    NaN               NaN
# 1103  SAS     3    844                    NaN               NaN
# 1104  SAS     3    844                    NaN               NaN
# 1105  SAS     3    844                    NaN               NaN
# 1106  SAS     3    844                    NaN               NaN
# 1107  SAS     3    844                    NaN               NaN
# Mismatches found for o_3pa:
#      tmID  year  o_3pa  sum_threeAttemptedPlayer  diff_threeAttempted
# 1057  SAS     1    262                       NaN                  NaN
# 1058  SAS     1    262                       NaN                  NaN
# 1059  SAS     1    262                       NaN                  NaN
# 1060  SAS     1    262                       NaN                  NaN
# 1061  SAS     1    262                       NaN                  NaN
# 1062  SAS     1    262                       NaN                  NaN
# 1063  SAS     1    262                       NaN                  NaN
# 1064  SAS     1    262                       NaN                  NaN
# 1065  SAS     1    262                       NaN                  NaN
# 1066  SAS     1    262                       NaN                  NaN
# 1067  SAS     1    262                       NaN                  NaN
# 1068  SAS     1    262                       NaN                  NaN
# 1069  SAS     1    262                       NaN                  NaN
# 1070  SAS     1    262                       NaN                  NaN
# 1071  SAS     2    244                       NaN                  NaN
# 1072  SAS     2    244                       NaN                  NaN
# 1073  SAS     2    244                       NaN                  NaN
# 1074  SAS     2    244                       NaN                  NaN
# 1075  SAS     2    244                       NaN                  NaN
# 1076  SAS     2    244                       NaN                  NaN
# 1077  SAS     2    244                       NaN                  NaN
# 1078  SAS     2    244                       NaN                  NaN
# 1079  SAS     2    244                       NaN                  NaN
# 1080  SAS     2    244                       NaN                  NaN
# ...
# 1089  SAS     2     775                  NaN             NaN
# 1090  SAS     2     775                  NaN             NaN
# 1091  SAS     2     775                  NaN             NaN
# 1092  SAS     2     775                  NaN             NaN
# 1093  SAS     2     775                  NaN             NaN
# 1094  SAS     2     775                  NaN             NaN
# 1095  SAS     3     721                  NaN             NaN
# 1096  SAS     3     721                  NaN             NaN
# 1097  SAS     3     721                  NaN             NaN
# 1098  SAS     3     721                  NaN             NaN
# 1099  SAS     3     721                  NaN             NaN
# 1100  SAS     3     721                  NaN             NaN
# 1101  SAS     3     721                  NaN             NaN
# 1102  SAS     3     721                  NaN             NaN
# 1103  SAS     3     721                  NaN             NaN
# 1104  SAS     3     721                  NaN             NaN
# 1105  SAS     3     721                  NaN             NaN
# 1106  SAS     3     721                  NaN             NaN
# 1107  SAS     3     721                  NaN             NaN
# Mismatches found for o_reb:
#      tmID  year  o_reb  sum_reboundsPlayer  diff_rebounds
# 1057  SAS     1   1080                 NaN            NaN
# 1058  SAS     1   1080                 NaN            NaN
# 1059  SAS     1   1080                 NaN            NaN
# 1060  SAS     1   1080                 NaN            NaN
# 1061  SAS     1   1080                 NaN            NaN
# 1062  SAS     1   1080                 NaN            NaN
# 1063  SAS     1   1080                 NaN            NaN
# 1064  SAS     1   1080                 NaN            NaN
# 1065  SAS     1   1080                 NaN            NaN
# 1066  SAS     1   1080                 NaN            NaN
# 1067  SAS     1   1080                 NaN            NaN
# 1068  SAS     1   1080                 NaN            NaN
# 1069  SAS     1   1080                 NaN            NaN
# 1070  SAS     1   1080                 NaN            NaN
# 1071  SAS     2   1070                 NaN            NaN
# 1072  SAS     2   1070                 NaN            NaN
# 1073  SAS     2   1070                 NaN            NaN
# 1074  SAS     2   1070                 NaN            NaN
# 1075  SAS     2   1070                 NaN            NaN
# 1076  SAS     2   1070                 NaN            NaN
# 1077  SAS     2   1070                 NaN            NaN
# 1078  SAS     2   1070                 NaN            NaN
# 1079  SAS     2   1070                 NaN            NaN
# 1080  SAS     2   1070                 NaN            NaN
# 1081  SAS     2   1070                 NaN            NaN
# 1082  SAS     2   1070                 NaN            NaN
# 1083  SAS     2   1070                 NaN            NaN
# 1084  SAS     2   1070                 NaN            NaN
# 1085  SAS     2   1070                 NaN            NaN
# 1086  SAS     2   1070                 NaN            NaN
# 1087  SAS     2   1070                 NaN            NaN
# 1088  SAS     2   1070                 NaN            NaN
# 1089  SAS     2   1070                 NaN            NaN
# 1090  SAS     2   1070                 NaN            NaN
# 1091  SAS     2   1070                 NaN            NaN
# 1092  SAS     2   1070                 NaN            NaN
# 1093  SAS     2   1070                 NaN            NaN
# 1094  SAS     2   1070                 NaN            NaN
# 1095  SAS     3   1068                 NaN            NaN
# 1096  SAS     3   1068                 NaN            NaN
# 1097  SAS     3   1068                 NaN            NaN
# 1098  SAS     3   1068                 NaN            NaN
# 1099  SAS     3   1068                 NaN            NaN
# 1100  SAS     3   1068                 NaN            NaN
# 1101  SAS     3   1068                 NaN            NaN
# 1102  SAS     3   1068                 NaN            NaN
# 1103  SAS     3   1068                 NaN            NaN
# 1104  SAS     3   1068                 NaN            NaN
# 1105  SAS     3   1068                 NaN            NaN
# 1106  SAS     3   1068                 NaN            NaN
# 1107  SAS     3   1068                 NaN            NaN
# Mismatches found for o_asts:
#      tmID  year  o_asts  sum_assistsPlayer  diff_assists
# 1057  SAS     1     522                NaN           NaN
# 1058  SAS     1     522                NaN           NaN
# 1059  SAS     1     522                NaN           NaN
# 1060  SAS     1     522                NaN           NaN
# 1061  SAS     1     522                NaN           NaN
# 1062  SAS     1     522                NaN           NaN
# 1063  SAS     1     522                NaN           NaN
# 1064  SAS     1     522                NaN           NaN
# 1065  SAS     1     522                NaN           NaN
# 1066  SAS     1     522                NaN           NaN
# 1067  SAS     1     522                NaN           NaN
# 1068  SAS     1     522                NaN           NaN
# 1069  SAS     1     522                NaN           NaN
# 1070  SAS     1     522                NaN           NaN
# 1071  SAS     2     524                NaN           NaN
# 1072  SAS     2     524                NaN           NaN
# 1073  SAS     2     524                NaN           NaN
# 1074  SAS     2     524                NaN           NaN
# 1075  SAS     2     524                NaN           NaN
# 1076  SAS     2     524                NaN           NaN
# 1077  SAS     2     524                NaN           NaN
# 1078  SAS     2     524                NaN           NaN
# 1079  SAS     2     524                NaN           NaN
# 1080  SAS     2     524                NaN           NaN
# 1081  SAS     2     524                NaN           NaN
# 1082  SAS     2     524                NaN           NaN
# 1083  SAS     2     524                NaN           NaN
# 1084  SAS     2     524                NaN           NaN
# 1085  SAS     2     524                NaN           NaN
# 1086  SAS     2     524                NaN           NaN
# 1087  SAS     2     524                NaN           NaN
# 1088  SAS     2     524                NaN           NaN
# 1089  SAS     2     524                NaN           NaN
# 1090  SAS     2     524                NaN           NaN
# 1091  SAS     2     524                NaN           NaN
# 1092  SAS     2     524                NaN           NaN
# 1093  SAS     2     524                NaN           NaN
# 1094  SAS     2     524                NaN           NaN
# 1095  SAS     3     478                NaN           NaN
# 1096  SAS     3     478                NaN           NaN
# 1097  SAS     3     478                NaN           NaN
# 1098  SAS     3     478                NaN           NaN
# 1099  SAS     3     478                NaN           NaN
# 1100  SAS     3     478                NaN           NaN
# 1101  SAS     3     478                NaN           NaN
# 1102  SAS     3     478                NaN           NaN
# 1103  SAS     3     478                NaN           NaN
# 1104  SAS     3     478                NaN           NaN
# 1105  SAS     3     478                NaN           NaN
# 1106  SAS     3     478                NaN           NaN
# 1107  SAS     3     478                NaN           NaN
# Mismatches found for o_stl:
#      tmID  year  o_stl  sum_stealsPlayer  diff_steals
# 1057  SAS     1    214               NaN          NaN
# 1058  SAS     1    214               NaN          NaN
# 1059  SAS     1    214               NaN          NaN
# 1060  SAS     1    214               NaN          NaN
# 1061  SAS     1    214               NaN          NaN
# 1062  SAS     1    214               NaN          NaN
# 1063  SAS     1    214               NaN          NaN
# 1064  SAS     1    214               NaN          NaN
# 1065  SAS     1    214               NaN          NaN
# 1066  SAS     1    214               NaN          NaN
# 1067  SAS     1    214               NaN          NaN
# 1068  SAS     1    214               NaN          NaN
# 1069  SAS     1    214               NaN          NaN
# 1070  SAS     1    214               NaN          NaN
# 1071  SAS     2    202               NaN          NaN
# 1072  SAS     2    202               NaN          NaN
# 1073  SAS     2    202               NaN          NaN
# 1074  SAS     2    202               NaN          NaN
# 1075  SAS     2    202               NaN          NaN
# 1076  SAS     2    202               NaN          NaN
# 1077  SAS     2    202               NaN          NaN
# 1078  SAS     2    202               NaN          NaN
# 1079  SAS     2    202               NaN          NaN
# 1080  SAS     2    202               NaN          NaN
# 1081  SAS     2    202               NaN          NaN
# 1082  SAS     2    202               NaN          NaN
# 1083  SAS     2    202               NaN          NaN
# 1084  SAS     2    202               NaN          NaN
# 1085  SAS     2    202               NaN          NaN
# 1086  SAS     2    202               NaN          NaN
# 1087  SAS     2    202               NaN          NaN
# 1088  SAS     2    202               NaN          NaN
# 1089  SAS     2    202               NaN          NaN
# 1090  SAS     2    202               NaN          NaN
# 1091  SAS     2    202               NaN          NaN
# 1092  SAS     2    202               NaN          NaN
# 1093  SAS     2    202               NaN          NaN
# 1094  SAS     2    202               NaN          NaN
# 1095  SAS     3    228               NaN          NaN
# 1096  SAS     3    228               NaN          NaN
# 1097  SAS     3    228               NaN          NaN
# 1098  SAS     3    228               NaN          NaN
# 1099  SAS     3    228               NaN          NaN
# 1100  SAS     3    228               NaN          NaN
# 1101  SAS     3    228               NaN          NaN
# 1102  SAS     3    228               NaN          NaN
# 1103  SAS     3    228               NaN          NaN
# 1104  SAS     3    228               NaN          NaN
# 1105  SAS     3    228               NaN          NaN
# 1106  SAS     3    228               NaN          NaN
# 1107  SAS     3    228               NaN          NaN
# Mismatches found for o_to:
#      tmID  year  o_to  sum_turnoversPlayer  diff_turnovers
# 1057  SAS     1   538                  NaN             NaN
# 1058  SAS     1   538                  NaN             NaN
# 1059  SAS     1   538                  NaN             NaN
# 1060  SAS     1   538                  NaN             NaN
# 1061  SAS     1   538                  NaN             NaN
# 1062  SAS     1   538                  NaN             NaN
# 1063  SAS     1   538                  NaN             NaN
# 1064  SAS     1   538                  NaN             NaN
# 1065  SAS     1   538                  NaN             NaN
# 1066  SAS     1   538                  NaN             NaN
# 1067  SAS     1   538                  NaN             NaN
# 1068  SAS     1   538                  NaN             NaN
# 1069  SAS     1   538                  NaN             NaN
# 1070  SAS     1   538                  NaN             NaN
# 1071  SAS     2   484                  NaN             NaN
# 1072  SAS     2   484                  NaN             NaN
# 1073  SAS     2   484                  NaN             NaN
# 1074  SAS     2   484                  NaN             NaN
# 1075  SAS     2   484                  NaN             NaN
# 1076  SAS     2   484                  NaN             NaN
# 1077  SAS     2   484                  NaN             NaN
# 1078  SAS     2   484                  NaN             NaN
# 1079  SAS     2   484                  NaN             NaN
# 1080  SAS     2   484                  NaN             NaN
# 1081  SAS     2   484                  NaN             NaN
# 1082  SAS     2   484                  NaN             NaN
# 1083  SAS     2   484                  NaN             NaN
# 1084  SAS     2   484                  NaN             NaN
# 1085  SAS     2   484                  NaN             NaN
# 1086  SAS     2   484                  NaN             NaN
# 1087  SAS     2   484                  NaN             NaN
# 1088  SAS     2   484                  NaN             NaN
# 1089  SAS     2   484                  NaN             NaN
# 1090  SAS     2   484                  NaN             NaN
# 1091  SAS     2   484                  NaN             NaN
# 1092  SAS     2   484                  NaN             NaN
# 1093  SAS     2   484                  NaN             NaN
# 1094  SAS     2   484                  NaN             NaN
# 1095  SAS     3   509                  NaN             NaN
# 1096  SAS     3   509                  NaN             NaN
# 1097  SAS     3   509                  NaN             NaN
# 1098  SAS     3   509                  NaN             NaN
# 1099  SAS     3   509                  NaN             NaN
# 1100  SAS     3   509                  NaN             NaN
# 1101  SAS     3   509                  NaN             NaN
# 1102  SAS     3   509                  NaN             NaN
# 1103  SAS     3   509                  NaN             NaN
# 1104  SAS     3   509                  NaN             NaN
# 1105  SAS     3   509                  NaN             NaN
# 1106  SAS     3   509                  NaN             NaN
# 1107  SAS     3   509                  NaN             NaN
# Mismatches found for o_blk:
#      tmID  year  o_blk  sum_blocksPlayer  diff_blocks
# 1057  SAS     1    157               NaN          NaN
# 1058  SAS     1    157               NaN          NaN
# 1059  SAS     1    157               NaN          NaN
# 1060  SAS     1    157               NaN          NaN
# 1061  SAS     1    157               NaN          NaN
# 1062  SAS     1    157               NaN          NaN
# 1063  SAS     1    157               NaN          NaN
# 1064  SAS     1    157               NaN          NaN
# 1065  SAS     1    157               NaN          NaN
# 1066  SAS     1    157               NaN          NaN
# 1067  SAS     1    157               NaN          NaN
# 1068  SAS     1    157               NaN          NaN
# 1069  SAS     1    157               NaN          NaN
# 1070  SAS     1    157               NaN          NaN
# 1071  SAS     2    156               NaN          NaN
# 1072  SAS     2    156               NaN          NaN
# 1073  SAS     2    156               NaN          NaN
# 1074  SAS     2    156               NaN          NaN
# 1075  SAS     2    156               NaN          NaN
# 1076  SAS     2    156               NaN          NaN
# 1077  SAS     2    156               NaN          NaN
# 1078  SAS     2    156               NaN          NaN
# 1079  SAS     2    156               NaN          NaN
# 1080  SAS     2    156               NaN          NaN
# 1081  SAS     2    156               NaN          NaN
# 1082  SAS     2    156               NaN          NaN
# 1083  SAS     2    156               NaN          NaN
# 1084  SAS     2    156               NaN          NaN
# 1085  SAS     2    156               NaN          NaN
# 1086  SAS     2    156               NaN          NaN
# 1087  SAS     2    156               NaN          NaN
# 1088  SAS     2    156               NaN          NaN
# 1089  SAS     2    156               NaN          NaN
# 1090  SAS     2    156               NaN          NaN
# 1091  SAS     2    156               NaN          NaN
# 1092  SAS     2    156               NaN          NaN
# 1093  SAS     2    156               NaN          NaN
# 1094  SAS     2    156               NaN          NaN
# 1095  SAS     3    178               NaN          NaN
# 1096  SAS     3    178               NaN          NaN
# 1097  SAS     3    178               NaN          NaN
# 1098  SAS     3    178               NaN          NaN
# 1099  SAS     3    178               NaN          NaN
# 1100  SAS     3    178               NaN          NaN
# 1101  SAS     3    178               NaN          NaN
# 1102  SAS     3    178               NaN          NaN
# 1103  SAS     3    178               NaN          NaN
# 1104  SAS     3    178               NaN          NaN
# 1105  SAS     3    178               NaN          NaN
# 1106  SAS     3    178               NaN          NaN
# 1107  SAS     3    178               NaN          NaN

# %% [markdown]
# Two teams (one from the East and one from the West) changed their names starting from year 4. We decided to update the tmID and the team name to the most recent ones for years 1, 2, and 3.

# %%
teams_EA = pd.read_csv('../newData/teams_EA_cleaned.csv')
teams_EA.loc[teams_EA['tmID'] == 'ORL', 'tmID'] = 'CON'
teams_EA.loc[teams_EA['tmID'] == 'CON', 'name'] = 'Connecticut Sun'
teams_EA.to_csv('../newData/teams_EA_cleaned.csv', index=False)

teams_WE = pd.read_csv('../newData/teams_WE_cleaned.csv')
teams_WE.loc[teams_WE['tmID'] == 'UTA', 'tmID'] = 'SAS'
teams_WE.loc[teams_WE['tmID'] == 'SAS', 'name'] = 'San Antonio Silver Stars'
teams_WE.to_csv('../newData/teams_WE_cleaned.csv', index=False)

# %% [markdown]
# ### Merge of the two tables

# %%
df_ea = pd.read_csv('../newData/teams_EA_cleaned.csv')
df_we = pd.read_csv('../newData/teams_WE_cleaned.csv')

combined_df = pd.concat([df_ea, df_we], ignore_index=True)
combined_df.to_csv('../newData/combined_teams.csv', index=False)

# %%
df = pd.read_csv('../newData/combined_teams.csv')
target = "playoff"

#Calculate the win rate of each team
df['winrate'] = df['won_x'] / df['GP_x'] * 100

df.to_csv('../newData/combined_teams.csv', index=False)

# %%
import pandas as pd

TPI_weights = {
    'o_pts': 1,       
    'o_fgm': 1,       
    'o_3pm': 1,       
    'o_ftm': 1,       
    'o_reb': 1,       
    'o_asts': 1,     
    'o_to': -1,       
    'o_pf': -1,       
    'd_reb': 1,       
    'd_stl': 1,       
    'd_blk': 1,      
    'd_pts': -1,      
    'd_pf': -1,       
    'd_to': 1       
}

# upload the dataset
df = pd.read_csv('../newData/combined_teams.csv')
# calculate 'TPI_Sum' for each team and year
df['TPI_Sum'] = 0
for index, row in df.iterrows():
    TPI_sum = sum(row[stat] * weight for stat, weight in TPI_weights.items() if stat in row)
    df.at[index, 'TPI_Sum'] = TPI_sum

# remove columns used to calculate TPI_Sum
columns_to_remove = list(TPI_weights.keys())
df.drop(columns=columns_to_remove, inplace=True)

# %% [markdown]
# # Transformation

# %% [markdown]
# ### Eliminating Useless Attributes

# %%
df.drop(
    [
        "franchID",
        "won_x",
        "lost_x",
        "homeW",
        "homeL",
        "awayW",
        "awayL",
        "name",
        "confW",
        "confL",
        "min",
        "attend",
        "arena",
        "GP_y",
        "GP_x",
        "stint_x",
        "points",
        "PF",
        "GS",
        "minutes",
        "dq",
        "PostGP",
        "PostGS",
        "GS",
        "stint_y",
        "won_y",
        "lost_y",
    ],
    axis=1, inplace=True,
)

# %% [markdown]
# ## Preparing Data

# %% [markdown]
#  Counting the games each team played in the postseason

# %%
mapping = {"L": 1, "W": 1, "N": 0}
for col in ["semis", "finals", "firstRound"]:
    df[col] = df[col].map(mapping)
df["roundsPlayed"] = df[["semis", "finals", "firstRound"]].sum(axis=1)

df.drop(["semis", "finals", "firstRound"], axis=1, inplace=True)

# %% [markdown]
# Calculating the mean of the height, weight and the age of the teams and the sum of the awards collected by players and coaches for each team for every year

# %%
new_df = pd.DataFrame()
for year in df["year"].unique():
    for team in df["tmID"].unique():
        small_df = df[(df["tmID"] == team) & (df["year"] == year)]
        if small_df.empty:
            continue

        d = pd.DataFrame([small_df.iloc[0]])
        d.fillna(0, inplace=True)
        d["award_player"] = small_df["award_x"].count()
        d["award_coach"] = d["award_y"].apply(lambda i: 1 if i != 0 else 0)
        d["height"] = small_df["height"].mean()
        d["weight"] = small_df["weight"].mean()
        d["playersAge"] = (2000 + df["year"]) - util.get_overall_age(
            small_df["birthDate"]
        )
        d.drop("playerID", axis=1, inplace=True)
        d.drop("birthDate", axis=1, inplace=True)
        d.drop("award_x", axis=1, inplace=True)
        d.drop("award_y", axis=1, inplace=True)
        d.drop("coachID", axis=1, inplace=True)

        new_df = pd.concat([new_df, d])

df = new_df.sort_values(by=["year", "tmID"])

# %% [markdown]
# # Future Encoding

# %% [markdown]
# This section of the code uses LabelEncoder to transform categorical variables into numerical values and separates the columns based on the type of variable

# %%
le = LabelEncoder()
df[target] = le.fit_transform(df[target])
df["confID"] = le.fit_transform(df["confID"])

#These columns contain key information that are used as predictive variables.
key_cols = ["confID", "year", "playoff", "tmID"]

numerical_cols = [col for col in df.columns if col not in key_cols]

# %% [markdown]
# ## Scaling of Numerical Variables

# %%
def custom_scaling(df, numerical_cols):
    """
    Apply StandardScaler to columns with Gaussian distribution,
    and MinMaxScaler to other columns.

    Parameters:
    - df: DataFrame to scale
    - numerical_cols: List of numerical columns to scale

    Returns:
    - Scaled DataFrame
    """
    gaussian_cols = []
    other_cols = []

    # Identifying columns based on Gaussian distribution
    for col in numerical_cols:
        if abs(df[col].skew()) < 0.5:  # Assuming skewness < 0.5 indicates Gaussian
            gaussian_cols.append(col)
        else:
            other_cols.append(col)

    # Scaling
    if gaussian_cols:
        df[gaussian_cols] = StandardScaler().fit_transform(df[gaussian_cols])
    if other_cols:
        df[other_cols] = MinMaxScaler().fit_transform(df[other_cols])

    return df

# %%
# Call the custom scaling function
df = custom_scaling(df, numerical_cols)

# Save the transformed DataFrame
df.to_csv('../newData/transformed_data.csv', index=False)

# %% [markdown]
# ### Adding PlayOffNextYear

# %%
df = pd.read_csv('../newData/transformed_data.csv')
df = df.sort_values(by=["tmID", "year"])
df['PlayOffNextYear'] = df['playoff'].shift(-1)
df.loc[df['tmID'] != df['tmID'].shift(-1), 'PlayOffNextYear'] = None
df.dropna(subset=['PlayOffNextYear'] , inplace=True)

# Imposta PlayOffNextYear a 0 per tutte le squadre dell'anno 10
transformed_data = pd.read_csv('../newData/transformed_data.csv')
y_filtered = transformed_data[transformed_data['year'] == 10]
y_filtered['PlayOffNextYear'] = np.nan

# Aggiungi le righe filtrate di y a x
df = pd.concat([df, y_filtered], ignore_index=True)
df = df.sort_values(by=["tmID", "year"])

df.to_csv('../newData/Shifted_playoff.csv', index=False)
# Out:
# <ipython-input-26-bb223d50fce9>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_filtered['PlayOffNextYear'] = np.nan
